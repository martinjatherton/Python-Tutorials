# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('europaFinal.csv')

# %%
df.head()
# Out:
#    minute  second             teamId     x     y     period   type  \
# 0       0     0.0  Manchester United   0.0   0.0  FirstHalf  Start
# 1       0     0.0         Villarreal   0.0   0.0  FirstHalf  Start
# 2       0     0.0  Manchester United  49.9  50.0  FirstHalf   Pass
# 3       0     3.0  Manchester United  32.2  58.1  FirstHalf   Pass
# 4       0    32.0         Villarreal  34.4   0.0  FirstHalf   Pass
#
#         outcome  playerId  endX   endY
# 0    Successful       NaN   NaN    NaN
# 1    Successful       NaN   NaN    NaN
# 2    Successful      18.0  31.5   59.6
# 3  Unsuccessful       2.0  69.6  100.0
# 4    Successful       8.0  36.5    9.5

# %%
df = df.loc[(df['teamId']=='Manchester United') & (df['playerId']==18) & (df['type']=='Pass') & (df['outcome']=='Successful')]

# %%
xT = pd.read_csv('xT.csv',header=None)
xT
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.006383  0.007796  0.008449  0.009777  0.011263  0.012483  0.014736
# 1  0.007501  0.008786  0.009424  0.010595  0.012147  0.013845  0.016118
# 2  0.008880  0.009777  0.010013  0.011105  0.012692  0.014291  0.016856
# 3  0.009411  0.010827  0.010165  0.011324  0.012626  0.014846  0.016895
# 4  0.009411  0.010827  0.010165  0.011324  0.012626  0.014846  0.016895
# 5  0.008880  0.009777  0.010013  0.011105  0.012692  0.014291  0.016856
# 6  0.007501  0.008786  0.009424  0.010595  0.012147  0.013845  0.016118
# 7  0.006383  0.007796  0.008449  0.009777  0.011263  0.012483  0.014736
#
#          7         8         9         10        11
# 0  0.017451  0.021221  0.027563  0.034851  0.037926
# 1  0.018703  0.024015  0.029533  0.040670  0.046477
# 2  0.019351  0.024122  0.028552  0.054911  0.064426
# 3  0.019971  0.023851  0.035113  0.108051  0.257454
# 4  0.019971  0.023851  0.035113  0.108051  0.257454
# 5  0.019351  0.024122  0.028552  0.054911  0.064426
# 6  0.018703  0.024015  0.029533  0.040670  0.046477
# 7  0.017451  0.021221  0.027563  0.034851  0.037926

# %%
xT = np.array(xT)

# %%
xT
# Out:
# array([[0.00638303, 0.00779616, 0.00844854, 0.00977659, 0.01126267,
#         0.01248344, 0.01473596, 0.0174506 , 0.02122129, 0.02756312,
#         0.03485072, 0.0379259 ],
#        [0.00750072, 0.00878589, 0.00942382, 0.0105949 , 0.01214719,
#         0.0138454 , 0.01611813, 0.01870347, 0.02401521, 0.02953272,
#         0.04066992, 0.04647721],
#        [0.0088799 , 0.00977745, 0.01001304, 0.01110462, 0.01269174,
#         0.01429128, 0.01685596, 0.01935132, 0.0241224 , 0.02855202,
#         0.05491138, 0.06442595],
#        [0.00941056, 0.01082722, 0.01016549, 0.01132376, 0.01262646,
#         0.01484598, 0.01689528, 0.0199707 , 0.02385149, 0.03511326,
#         0.10805102, 0.25745362],
#        [0.00941056, 0.01082722, 0.01016549, 0.01132376, 0.01262646,
#         0.01484598, 0.01689528, 0.0199707 , 0.02385149, 0.03511326,
#         0.10805102, 0.25745362],
#        [0.0088799 , 0.00977745, 0.01001304, 0.01110462, 0.01269174,
#         0.01429128, 0.01685596, 0.01935132, 0.0241224 , 0.02855202,
#         0.05491138, 0.06442595],
#        [0.00750072, 0.00878589, 0.00942382, 0.0105949 , 0.01214719,
#         0.0138454 , 0.01611813, 0.01870347, 0.02401521, 0.02953272,
#         0.04066992, 0.04647721],
#        [0.00638303, 0.00779616, 0.00844854, 0.00977659, 0.01126267,
#         0.01248344, 0.01473596, 0.0174506 , 0.02122129, 0.02756312,
#         0.03485072, 0.0379259 ]])

# %%
xT_rows, xT_cols = xT.shape

# %%
xT_cols
# Out:
# 12

# %%
df['x1_bin'] = pd.cut(df['x'], bins = xT_cols, labels=False)
df['y1_bin'] = pd.cut(df['y'], bins = xT_rows, labels=False)
df['x2_bin'] = pd.cut(df['endX'], bins = xT_cols, labels=False)
df['y2_bin'] = pd.cut(df['endY'], bins = xT_rows, labels=False)
# Out:
# <ipython-input-16-b0a8939c90ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x1_bin'] = pd.cut(df['x'], bins = xT_cols, labels=False)
# <ipython-input-16-b0a8939c90ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y1_bin'] = pd.cut(df['y'], bins = xT_rows, labels=False)
# <ipython-input-16-b0a8939c90ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x2_bin'] = pd.cut(df['endX'], bins = xT_cols, labels=False)
# <ipython-input-16-b0a8939c90ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y2_bin'] = pd.cut(df['endY'], bins = xT_rows, labels=False)

# %%
df.head()
# Out:
#      minute  second             teamId     x     y     period  type  \
# 2         0     0.0  Manchester United  49.9  50.0  FirstHalf  Pass
# 119       6    11.0  Manchester United  65.4  96.8  FirstHalf  Pass
# 130       6    55.0  Manchester United  69.8  30.3  FirstHalf  Pass
# 133       7     1.0  Manchester United  84.3  23.3  FirstHalf  Pass
# 185      12    20.0  Manchester United  39.0  64.8  FirstHalf  Pass
#
#         outcome  playerId  endX  endY  x1_bin  y1_bin  x2_bin  y2_bin
# 2    Successful      18.0  31.5  59.6       5       4       3       4
# 119  Successful      18.0  63.3  87.8       7       7       7       7
# 130  Successful      18.0  74.4  18.8       8       2       9       1
# 133  Successful      18.0  86.0  20.0      10       1      10       1
# 185  Successful      18.0  32.8  72.9       3       5       3       5

# %%
df['start_zone_value'] = df[['x1_bin','y1_bin']].apply(lambda x: xT[x[1]][x[0]],axis=1)
df['end_zone_value'] = df[['x2_bin','y2_bin']].apply(lambda x: xT[x[1]][x[0]],axis=1)
# Out:
# <ipython-input-18-2bbf19f6667c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['start_zone_value'] = df[['x1_bin','y1_bin']].apply(lambda x: xT[x[1]][x[0]],axis=1)
# <ipython-input-18-2bbf19f6667c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end_zone_value'] = df[['x2_bin','y2_bin']].apply(lambda x: xT[x[1]][x[0]],axis=1)

# %%
df.head()
# Out:
#      minute  second             teamId     x     y     period  type  \
# 2         0     0.0  Manchester United  49.9  50.0  FirstHalf  Pass
# 119       6    11.0  Manchester United  65.4  96.8  FirstHalf  Pass
# 130       6    55.0  Manchester United  69.8  30.3  FirstHalf  Pass
# 133       7     1.0  Manchester United  84.3  23.3  FirstHalf  Pass
# 185      12    20.0  Manchester United  39.0  64.8  FirstHalf  Pass
#
#         outcome  playerId  endX  endY  x1_bin  y1_bin  x2_bin  y2_bin  \
# 2    Successful      18.0  31.5  59.6       5       4       3       4
# 119  Successful      18.0  63.3  87.8       7       7       7       7
# 130  Successful      18.0  74.4  18.8       8       2       9       1
# 133  Successful      18.0  86.0  20.0      10       1      10       1
# 185  Successful      18.0  32.8  72.9       3       5       3       5
#
#      start_zone_value  end_zone_value
# 2            0.014846        0.011324
# 119          0.017451        0.017451
# 130          0.024122        0.029533
# 133          0.040670        0.040670
# 185          0.011105        0.011105

# %%
df['xT'] = df['end_zone_value'] - df['start_zone_value']
# Out:
# <ipython-input-21-a267dce9eb99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xT'] = df['end_zone_value'] - df['start_zone_value']

# %%
df.head()
# Out:
#      minute  second             teamId     x     y     period  type  \
# 2         0     0.0  Manchester United  49.9  50.0  FirstHalf  Pass
# 119       6    11.0  Manchester United  65.4  96.8  FirstHalf  Pass
# 130       6    55.0  Manchester United  69.8  30.3  FirstHalf  Pass
# 133       7     1.0  Manchester United  84.3  23.3  FirstHalf  Pass
# 185      12    20.0  Manchester United  39.0  64.8  FirstHalf  Pass
#
#         outcome  playerId  endX  endY  x1_bin  y1_bin  x2_bin  y2_bin  \
# 2    Successful      18.0  31.5  59.6       5       4       3       4
# 119  Successful      18.0  63.3  87.8       7       7       7       7
# 130  Successful      18.0  74.4  18.8       8       2       9       1
# 133  Successful      18.0  86.0  20.0      10       1      10       1
# 185  Successful      18.0  32.8  72.9       3       5       3       5
#
#      start_zone_value  end_zone_value        xT
# 2            0.014846        0.011324 -0.003522
# 119          0.017451        0.017451  0.000000
# 130          0.024122        0.029533  0.005410
# 133          0.040670        0.040670  0.000000
# 185          0.011105        0.011105  0.000000

# %%
df
# Out:
#       minute  second             teamId     x     y                   period  \
# 2          0     0.0  Manchester United  49.9  50.0                FirstHalf
# 119        6    11.0  Manchester United  65.4  96.8                FirstHalf
# 130        6    55.0  Manchester United  69.8  30.3                FirstHalf
# 133        7     1.0  Manchester United  84.3  23.3                FirstHalf
# 185       12    20.0  Manchester United  39.0  64.8                FirstHalf
# 197       12    50.0  Manchester United  43.0  70.0                FirstHalf
# 286       19     9.0  Manchester United  69.5  74.5                FirstHalf
# 336       22    57.0  Manchester United  37.0  89.6                FirstHalf
# 366       24    43.0  Manchester United  71.7  24.6                FirstHalf
# 434       30     5.0  Manchester United  49.9  50.1                FirstHalf
# 473       31    58.0  Manchester United  65.4  77.9                FirstHalf
# 514       33    31.0  Manchester United  64.9  76.7                FirstHalf
# 516       33    37.0  Manchester United  59.8  88.1                FirstHalf
# 523       34     4.0  Manchester United  69.6  73.6                FirstHalf
# 581       37     3.0  Manchester United  58.8  94.2                FirstHalf
# 676       42    12.0  Manchester United  65.8  70.9                FirstHalf
# 679       42    21.0  Manchester United  60.9  69.4                FirstHalf
# 716       44    12.0  Manchester United  70.1  26.8                FirstHalf
# 752       45    12.0  Manchester United  67.9  29.1                FirstHalf
# 789       45    31.0  Manchester United  37.6  80.9               SecondHalf
# 838       47    46.0  Manchester United  24.3  65.1               SecondHalf
# 879       49    22.0  Manchester United  41.5   9.2               SecondHalf
# 884       49    34.0  Manchester United  56.5   7.7               SecondHalf
# 887       49    46.0  Manchester United  70.3  33.9               SecondHalf
# 970       56    26.0  Manchester United  63.8  18.2               SecondHalf
# 974       56    33.0  Manchester United  69.6   2.2               SecondHalf
# 1141      64    54.0  Manchester United  67.8  75.7               SecondHalf
# 1144      65     3.0  Manchester United  73.5  79.9               SecondHalf
